# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
img = cv2.imread('data/paimeng.png')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

height = img.shape[0]
width = img.shape[1]

plt.figure()
plt.imshow(gray, "gray")
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ## 大津法

# %%
def OTSU(gray):
    hist = cv2.calcHist([gray], [0], None, [256], [0, 256])
    hist = hist / (height * width)
    threshold = 0
    maxVariance = 0
    for i in range(256):
        w0 = np.sum(hist[:i])
        w1 = np.sum(hist[i:])
        u0 = np.sum(np.multiply(hist[:i], np.arange(i))) / w0
        u1 = np.sum(np.multiply(hist[i:], np.arange(i, 256))) / w1
        variance = w0 * w1 * (u0 - u1) ** 2
        if variance > maxVariance:
            maxVariance = variance
            threshold = i
    return threshold

# %%
_, result = cv2.threshold(gray, OTSU(gray), 255, cv2.THRESH_BINARY)

plt.figure(figsize=(12,6))
plt.subplot(121)
plt.imshow(gray, "gray")
plt.xticks([]), plt.yticks([])
plt.subplot(122)
plt.imshow(result, "gray")
plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# <ipython-input-5-278b6e7edbb6>:9: RuntimeWarning: invalid value encountered in double_scalars
#   u0 = np.sum(np.multiply(hist[:i], np.arange(i))) / w0
# <ipython-input-5-278b6e7edbb6>:10: RuntimeWarning: invalid value encountered in double_scalars
#   u1 = np.sum(np.multiply(hist[i:], np.arange(i, 256))) / w1

# %% [markdown]
# ## 自适应阈值-迭代法

# %%
def Iteration(gray):
    hist = cv2.calcHist([gray], [0], None, [256], [0, 256])
    img_array = np.array(gray).astype(np.float32)
    zmax, zmin = np.max(img_array), np.min(img_array)
    t0 = int((zmax + zmin) / 2)
    b = 1
    
    while True:
        w0 = np.sum(hist[:t0])
        w1 = np.sum(hist[t0:])
        u0 = np.sum(np.multiply(hist[:t0], np.arange(t0))) / w0
        u1 = np.sum(np.multiply(hist[t0:], np.arange(t0, 256))) / w1
        
        t1 = int((u0 + u1) / 2)
        if math.fabs(t1-t0)<50:
            break
        else:
            to = t1
            
    return t1

# %%
_, result = cv2.threshold(gray, Iteration(gray), 255, cv2.THRESH_BINARY)

plt.figure(figsize=(10, 12))
plt.subplot(121), plt.imshow(gray, 'gray'), plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(result, 'gray'), plt.xticks([]), plt.yticks([])
plt.tight_layout()
plt.show()
